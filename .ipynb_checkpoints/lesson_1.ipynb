# %% [markdown]
# > Hello this is my interactive python notebook for data Science </p>

# %%
import matplotlib.pyplot as plt
print('hello')
y = [1,2,3,4]
x = [22 ,87 , 0, 18]

plt.plot(x,y)

plt.ylabel ("Memes")
plt.xlabel ("Derp")
plt.title('my will to live')
# Out:
# hello
# Text(0.5, 1.0, 'my will to live')

# %%
number = ['one', 'two', 'three', 'four']
count = [10, 30, 20, 10]
plt.bar(number, count)
plt.ylabel ('will')
plt.xlabel('Living')
plt.title('The will to live')
# Out:
# Text(0.5, 1.0, 'The will to live')

# %%
x = [10,20,30,10,15,7]

plt.pie(x)

plt.title('Pie of ez ratio <3')
# Out:
# Text(0.5, 1.0, 'Pie of ez ratio <3')

# %% [markdown]
# # File Operations
# In this excercise you will begin working on using the `open` function within python to manipulate files and create reports on those files.
#
# **YOU ARE TO INCLUDE COMMENTS ALONG SIDE YOUR CODE**

# %% [markdown]
# 1. Open the file "states.txt" that you downloaded, what does this file contain?
# ```
#
# ```

# %% [markdown]
# *Use the code block below to open the same file, using a `for` loop print each line to the console.*

# %%
#Imports pyplot sub module as plt in matplotlib
import matplotlib.pyplot as plt

#Lables the states text file as stateslist
stateslists = open ('states.txt')

#With function helps with staying resourceful on the states file
with open("states.txt") as statelist :
    #Relables statelist as state
    state = statelist.readlines()
#For loop to print all states in text file
for x in state:
    print(x)
# Out:
# WA
#
# MO
#
# KS
#
# SC
#
# GA
#
# FL
#
# MN
#
# NC
#
# HI
#
# CT
#
# TX
#
# MA
#
# OK
#
# IL
#
# HI
#
# CA
#
# TX
#
# WA
#
# OH
#
# PA
#
# MO
#
# IL
#
# CA
#
# IL
#
# CA
#
# DC
#
# FL
#
# NC
#
# NY
#
# VA
#
# TX
#
# CA
#
# DC
#
# TX
#
# OH
#
# WA
#
# FL
#
# MN
#
# DC
#
# FL
#
# CA
#
# FL
#
# TX
#
# CT
#
# NC
#
# MO
#
# TX
#
# MA
#
# TX
#
# WA
#
# IN
#
# IN
#
# MO
#
# AL
#
# OK
#
# GA
#
# NY
#
# IN
#
# OK
#
# IN
#
# CA
#
# GA
#
# CA
#
# CA
#
# IN
#
# NY
#
# MS
#
# CA
#
# NV
#
# ID
#
# MN
#
# VA
#
# WY
#
# WV
#
# MN
#
# MO
#
# TX
#
# MA
#
# IN
#
# IA
#
# WA
#
# MN
#
# CA
#
# NE
#
# IL
#
# IL
#
# PA
#
# GA
#
# TX
#
# OH
#
# DE
#
# TX
#
# NM
#
# TX
#
# MA
#
# LA
#
# GA
#
# TN
#
# CA
#
# DC
#
# FL
#
# CO
#
# MI
#
# MD
#
# FL
#
# FL
#
# NC
#
# OH
#
# IA
#
# NE
#
# TX
#
# IN
#
# TX
#
# CA
#
# TX
#
# IL
#
# CA
#
# VA
#
# TX
#
# CA
#
# NY
#
# IN
#
# NY
#
# OH
#
# NY
#
# TN
#
# DC
#
# CA
#
# MN
#
# VA
#
# UT
#
# NH
#
# TX
#
# CA
#
# PA
#
# CO
#
# TX
#
# FL
#
# CA
#
# PA
#
# OH
#
# MD
#
# CT
# ...

# %% [markdown]
# 2. What type of chart would be best to represent this data? Explain why
# ```
# A bar graph would be the best form of representation towards this data because it'll show each state that's placed to be graphed as well as their appropriate values.
# ```
# 3. How would we need to transform the data we have, to be displayed in this chart?
# ```
# To transform the data to display into this chart, we'd go by using two variables. One variable will be on the x-axis graping the names, whilst one will be on the y-axis graphing their appropriate values.
# ```

# %% [markdown]
# Using your knowledge of Python and Matplotlib write your code to transform and graph the data below.
#
# After your code create a new Markdown block to describe your analysis

# %%
#Manually and painfully writing down each state intial one by one with a value of 0
AL = 0
AK = 0
AZ = 0
AR = 0
AS = 0
CA = 0
CO = 0
CT = 0
DE = 0
DC = 0
FL = 0
GA = 0
GU = 0
HI = 0
ID = 0
IL = 0
IN = 0
IA = 0
KS = 0
KY = 0
LA = 0
ME = 0
MD = 0
MA = 0
MI = 0
MN = 0
MS = 0
MO = 0
MT = 0
NE = 0
NV = 0
NH = 0
NJ = 0
NM = 0
NY = 0
NC = 0
ND = 0
MP = 0
OH = 0
OK = 0
OR = 0
PA = 0
PR = 0
RI = 0
SC = 0
SD = 0
TN = 0
TX = 0
TT = 0
UT = 0
VT = 0
VA = 0
VI = 0
WA = 0
WV = 0
WI = 0
WY = 0


#For loop that checks each item in text file
for x in state :
    #if statement with multiple elifs to check how many times a state was repeated (one for each state)
    if x == 'AL\n':
        AL +=1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AZ\n':
        AZ += 1
    elif x == 'AR\n':
        AR += 1
    elif x == 'CA\n':
        CA += 1
    elif x == 'CO\n':
        CO += 1
    elif x == 'CT\n':
        CT += 1
    elif x == 'DE\n':
        DE += 1
    elif x == 'FL\n':
        FL += 1
    elif x == 'GA\n':
        GA += 1
    elif x == 'HI\n':
        HI += 1
    elif x == 'ID\n':
        ID += 1
    elif x == 'IL\n':
        IL += 1
    elif x == 'IN\n':
        IN += 1
    elif x == 'IA\n':
        IA += 1
    elif x == 'KS\n':
        KS += 1
    elif x == 'KY\n':
        KY += 1
    elif x == 'LA\n':
        LA += 1
    elif x == 'ME\n':
        ME += 1
    elif x == 'MD\n':
        MD += 1
    elif x == 'MA\n':
        MA += 1
    elif x == 'MI\n':
        MI += 1
    elif x == 'MN\n':
        MN += 1
    elif x == 'MS\n':
        MS += 1
    elif x == 'MO\n':
        MO += 1
    elif x == 'MT\n':
        MT += 1
    elif x == 'NE\n':
        NE += 1
    elif x == 'NV\n':
        NV += 1
    elif x == 'NH\n':
        NH += 1
    elif x == 'NJ\n':
        NJ += 1
    elif x == 'NM\n':
        NM += 1
    elif x == 'NY\n':
        NY += 1
    elif x == 'NC\n':
        NC += 1
    elif x == 'ND\n':
        ND += 1
    elif x == 'OH\n':
        OH += 1
    elif x == 'OK\n':
        OK += 1
    elif x == 'OR\n':
        OR += 1
    elif x == 'PA\n':
        PA += 1
    elif x == 'RI\n':
        RI += 1
    elif x == 'SC\n':
        SC += 1
    elif x == 'SD\n':
        SD += 1
    elif x == 'TN\n':
        TN += 1
    elif x == 'TX\n':
        TX += 1   
    elif x == 'UT\n':
        UT += 1
    elif x == 'VT\n':
        VT += 1
    elif x == 'VA\n':
        VA += 1
    elif x == 'WA\n':
        WA += 1
    elif x == 'WV\n':
        WV += 1
    elif x == 'WI\n':
        WI += 1
    elif x == 'WY\n':
        WY += 1
    else:
        print()

#Resizes my bar graph to a readable scale
plt.rcParams["figure.figsize"] = (20, 15)

#Labling each state as an x value for name with a y value for appropriate numerical value
plt.bar(['AL', 'AK','AZ','AR','CA','CO','CT','DE','FL','GA','HI','ID','IL','IN','IA','KS','KY','LA','ME','MD','MA','MI','MN','MS','MO','MT','NE','NV','NH','NJ','NM','NY','NC','ND','OH','OK','OR','PA','RI','SC','SD','TN','TX','UT','VT','VA','WA','WV','WI','WY'],[AL, AK,AZ,AR,CA,CO,CT,DE,FL,GA,HI,ID,IL,IN,IA,KS,KY,LA,ME,MD,MA,MI,MN,MS,MO,MT,NE,NV,NH,NJ,NM,NY,NC,ND,OH,OK,OR,PA,RI,SC,SD,TN,TX,UT,VT,VA,WA,WV,WI,WY])
# Out:
# <BarContainer object of 50 artists>

# %% [markdown]
# This code refrences to a thousand line text file that has a repeating sequence of all 50 states in the United States. A for loop will go and check all the times a specific state intial was repeated and add a value of one to its variable whenever it's repeated. After all of that, all the variables will be connected to a bar graph that is imported from a sub module within matplotlib, this bar graph will display each of the 50 states an show how many times each state was writted.
